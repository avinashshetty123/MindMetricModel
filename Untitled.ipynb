# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming you've already loaded your dataset
df = pd.read_csv("train.csv")

# Separate the features (X) and target (y)
X = df.drop(columns=['condition', 'datasetId'])  # Drop target and irrelevant columns
y = df['condition']  # Target column

# Step 2: Handle missing values (if any)
# Replace missing values with column mean

# Step 3: Scale the features (important for Logistic Regression)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label encode the target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)  # This will convert y into 0, 1, 2, ...

# Step 2: Continue with the rest of the steps as before
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Logistic Regression Model
log_reg = LogisticRegression(max_iter=500)
log_reg.fit(X_train, y_train)

# Predictions
y_pred_log = log_reg.predict(X_test)

# Evaluate the model
print("🔹 Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_log)*100)
print(classification_report(y_test, y_pred_log))
# Out:
# 🔹 Logistic Regression Accuracy: 63.210484984700365
#               precision    recall  f1-score   support
#
#            0       0.61      0.41      0.49     31551
#            1       0.65      0.87      0.74     60027
#            2       0.52      0.26      0.35     19209
#
#     accuracy                           0.63    110787
#    macro avg       0.59      0.51      0.53    110787
# weighted avg       0.62      0.63      0.60    110787

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_rf)
print("🔹 Random Forest Accuracy:", accuracy)

# Detailed evaluation metrics
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))

# Confusion Matrix
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# 🔹 Random Forest Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31551
#            1       1.00      1.00      1.00     60027
#            2       1.00      1.00      1.00     19209
#
#     accuracy                           1.00    110787
#    macro avg       1.00      1.00      1.00    110787
# weighted avg       1.00      1.00      1.00    110787
#
#
# Confusion Matrix:
#  [[31551     0     0]
#  [    0 60027     0]
#  [    0     0 19209]]

# %%
df2=pd.read_csv("test.csv")

# %%
df2.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  721.901897  727.267280   74.722315  12.361264  12.361069    6.044877
# 1  843.538633  844.407930   58.499429  19.298880  19.298795    3.031234
# 2  958.523868  966.671125  132.849110  21.342715  21.342653    6.224565
# 3  824.838669  842.485905  117.822094  11.771814  11.771248   10.008830
# 4  756.707933  747.941620  143.968457  13.357748  13.356388   10.777899
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  84.121868   4.933333  0.000000   8.743513  ...  66.617057  3.921868
# 1  71.478642  21.000000  0.200000  13.650863  ...  26.500086  1.123416
# 2  63.874293  24.133333  1.800000  15.096571  ...  16.024935  0.370208
# 3  74.330531   4.733333  0.533333   8.326307  ...  17.581470  0.615932
# 4  82.092049   5.933333  0.666667   9.447545  ...  35.199054  0.662879
#
#       HF_NU           TP       LF_HF     HF_LF    sampen    higuci  datasetId  \
# ...

# %%
X1 = df2.drop(columns=['condition', 'datasetId'])  # Drop target and irrelevant columns
y1 = df2['condition']

# %%
scaler = StandardScaler()
X2_scale = scaler.fit_transform(X1)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label encode the target variable
label_encoder = LabelEncoder()
y1 = label_encoder.fit_transform(y1)

# %%
y_pred_rf = rf_model.predict(X2_scale)

# Evaluate the model
accuracy = accuracy_score(y1, y_pred_rf)
print("🔹 Random Forest Accuracy:", accuracy)

# Detailed evaluation metrics
print("\nClassification Report:\n", classification_report(y1, y_pred_rf))

# Confusion Matrix
print("\nConfusion Matrix:\n", confusion_matrix(y1, y_pred_rf))
# Out:
# 🔹 Random Forest Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11782
#            1       1.00      1.00      1.00     22158
#            2       1.00      1.00      1.00      7093
#
#     accuracy                           1.00     41033
#    macro avg       1.00      1.00      1.00     41033
# weighted avg       1.00      1.00      1.00     41033
#
#
# Confusion Matrix:
#  [[11782     0     0]
#  [    0 22158     0]
#  [    0     0  7093]]
